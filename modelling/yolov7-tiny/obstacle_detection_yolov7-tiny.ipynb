# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197
# Receiving objects: 100% (1197/1197), 74.23 MiB | 29.77 MiB/s, done.
# Resolving deltas: 100% (519/519), done.

# %%
# %cd /content/yolov7
# %pwd
# Out:
# /content/yolov7
# '/content/yolov7'

# %%
# !ls
# Out:
# cfg	detect.py  hubconf.py  models	  requirements.txt  tools	  utils
# data	export.py  inference   paper	  scripts	    train_aux.py
# deploy	figure	   LICENSE.md  README.md  test.py	    train.py

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 48.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 60.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 58.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 85.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.0 MB/s eta 0:00:00
# ...

# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=c9f1912fd4f34cf4762a020039b298fe3408e60f953fa797281fb765a463b509
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...

# %%
# !pip install PyYAML

# %%
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic # decorator
def writetemplate(line,cell):
  with open(line,'w') as f:
    f.write(cell.format(**globals()))

# %%
# !cat /content/drive/MyDrive/hjh_kita_directory/3rd_project/장애물탐지/obstacles_data/custom_data.yaml
# Out:
# names:
# - person
# - bicycle
# - car
# - motorcycle
# - bus
# - tree_trunk
# - traffic_light
# - stop
# - carrier
# - cat
# - dog
# - movable_signage
# - scooter
# - stroller
# - truck
# - wheelchair
# - barricade
# - bench
# - bollard
# - chair
# - fire_hydrant
# - kiosk
# - parking_meter
# - pole
# - potted_plant
# - power_controller
# - table
# - traffic_light_controller
# - traffic_sign
# nc: 29
# test: "/content/drive/MyDrive/hjh_kita_directory/3rd_project/\u110C\u1161\u11BC\u110B\
#   \u1162\u1106\u116E\u11AF\u1110\u1161\u11B7\u110C\u1175/obstacles_data/test/images"
# train: "/content/drive/MyDrive/hjh_kita_directory/3rd_project/\u110C\u1161\u11BC\u110B\
#   \u1162\u1106\u116E\u11AF\u1110\u1161\u11B7\u110C\u1175/obstacles_data/train/images"
# val: "/content/drive/MyDrive/hjh_kita_directory/3rd_project/\u110C\u1161\u11BC\u110B\
#   \u1162\u1106\u116E\u11AF\u1110\u1161\u11B7\u110C\u1175/obstacles_data/valid/images"

# %%
# !cp /content/drive/MyDrive/hjh_kita_directory/3rd_project/장애물탐지/obstacles_data/custom_data.yaml /content/drive/MyDrive/hjh_kita_directory/3rd_project/장애물탐지/obstacles_data_ver4/

# %%
import yaml

data = { 'train' : '/content/drive/MyDrive/hjh_kita_directory/3rd_project/장애물탐지/obstacles_data_ver4/train/images/',
         'val' : '/content/drive/MyDrive/hjh_kita_directory/3rd_project/장애물탐지/obstacles_data_ver4/valid/images/',
         'test' : '/content/drive/MyDrive/hjh_kita_directory/3rd_project/장애물탐지/obstacles_data_ver4/test/images/',
         'names' : ['person', 'bicycle', 'car', 'motorcycle', 'bus', 'tree_trunk', 'traffic_light', 'stop', 'carrier', 'cat', 'dog', 'movable_signage', 'scooter', 'stroller', 'truck', 'wheelchair', 'barricade', 'bench', 'bollard', 'chair', 'fire_hydrant', 'kiosk', 'parking_meter', 'pole', 'potted_plant', 'power_controller', 'table', 'traffic_light_controller', 'traffic_sign'],
         'nc' : 29 }

with open('/content/drive/MyDrive/hjh_kita_directory/3rd_project/장애물탐지/obstacles_data_ver4/custom_data.yaml', 'w') as f:
  yaml.dump(data, f)


with open('/content/drive/MyDrive/hjh_kita_directory/3rd_project/장애물탐지/obstacles_data_ver4/custom_data.yaml', 'r') as f:
  custom_data_yaml = yaml.safe_load(f)
  display(custom_data_yaml)
# Out:
# {'names': ['person',
#   'bicycle',
#   'car',
#   'motorcycle',
#   'bus',
#   'tree_trunk',
#   'traffic_light',
#   'stop',
#   'carrier',
#   'cat',
#   'dog',
#   'movable_signage',
#   'scooter',
#   'stroller',
#   'truck',
#   'wheelchair',
#   'barricade',
#   'bench',
#   'bollard',
#   'chair',
#   'fire_hydrant',
#   'kiosk',
#   'parking_meter',
#   'pole',
#   'potted_plant',
#   'power_controller',
#   'table',
#   'traffic_light_controller',
#   'traffic_sign'],
#  'nc': 29,
#  'test': '/content/drive/MyDrive/hjh_kita_directory/3rd_project/장애물탐지/obstacles_data_ver4/test/images/',
#  'train': '/content/drive/MyDrive/hjh_kita_directory/3rd_project/장애물탐지/obstacles_data_ver4/train/images/',
#  'val': '/content/drive/MyDrive/hjh_kita_directory/3rd_project/장애물탐지/obstacles_data_ver4/valid/images/'}

# %%
import yaml
with open('/content/drive/MyDrive/hjh_kita_directory/3rd_project/장애물탐지/obstacles_data_ver4/custom_data.yaml','r') as stream:
  num_classes = str(yaml.safe_load(stream)['nc'])
num_classes
# Out:
# '29'

# %%
# !cat /content/yolov7/cfg/training/yolov7.yaml
# Out:
# # parameters
# nc: 80  # number of classes
# depth_multiple: 1.0  # model depth multiple
# width_multiple: 1.0  # layer channel multiple
#
# # anchors
# anchors:
#   - [12,16, 19,36, 40,28]  # P3/8
#   - [36,75, 76,55, 72,146]  # P4/16
#   - [142,110, 192,243, 459,401]  # P5/32
#
# # yolov7 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [32, 3, 1]],  # 0
#
#    [-1, 1, Conv, [64, 3, 2]],  # 1-P1/2
#    [-1, 1, Conv, [64, 3, 1]],
#
#    [-1, 1, Conv, [128, 3, 2]],  # 3-P2/4
#    [-1, 1, Conv, [64, 1, 1]],
#    [-2, 1, Conv, [64, 1, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [[-1, -3, -5, -6], 1, Concat, [1]],
#    [-1, 1, Conv, [256, 1, 1]],  # 11
#
#    [-1, 1, MP, []],
#    [-1, 1, Conv, [128, 1, 1]],
#    [-3, 1, Conv, [128, 1, 1]],
#    [-1, 1, Conv, [128, 3, 2]],
#    [[-1, -3], 1, Concat, [1]],  # 16-P3/8
#    [-1, 1, Conv, [128, 1, 1]],
# ...

# %%
# %%writetemplate /content/yolov7/cfg/training/custom_yolov7.yaml
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 1.0  # model depth multiple
# width_multiple: 1.0  # layer channel multiple
#
# # anchors
# anchors:
#   - [12,16, 19,36, 40,28]  # P3/8
#   - [36,75, 76,55, 72,146]  # P4/16
#   - [142,110, 192,243, 459,401]  # P5/32
#
# # yolov7 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [32, 3, 1]],  # 0
#
#    [-1, 1, Conv, [64, 3, 2]],  # 1-P1/2
#    [-1, 1, Conv, [64, 3, 1]],
#
#    [-1, 1, Conv, [128, 3, 2]],  # 3-P2/4
#    [-1, 1, Conv, [64, 1, 1]],
#    [-2, 1, Conv, [64, 1, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [[-1, -3, -5, -6], 1, Concat, [1]],
#    [-1, 1, Conv, [256, 1, 1]],  # 11
#
#    [-1, 1, MP, []],
#    [-1, 1, Conv, [128, 1, 1]],
#    [-3, 1, Conv, [128, 1, 1]],
#    [-1, 1, Conv, [128, 3, 2]],
#    [[-1, -3], 1, Concat, [1]],  # 16-P3/8
#    [-1, 1, Conv, [128, 1, 1]],
#    [-2, 1, Conv, [128, 1, 1]],
#    [-1, 1, Conv, [128, 3, 1]],
#    [-1, 1, Conv, [128, 3, 1]],
#    [-1, 1, Conv, [128, 3, 1]],
#    [-1, 1, Conv, [128, 3, 1]],
#    [[-1, -3, -5, -6], 1, Concat, [1]],
#    [-1, 1, Conv, [512, 1, 1]],  # 24
#
#    [-1, 1, MP, []],
#    [-1, 1, Conv, [256, 1, 1]],
#    [-3, 1, Conv, [256, 1, 1]],
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, -3], 1, Concat, [1]],  # 29-P4/16
#    [-1, 1, Conv, [256, 1, 1]],
#    [-2, 1, Conv, [256, 1, 1]],
#    [-1, 1, Conv, [256, 3, 1]],
#    [-1, 1, Conv, [256, 3, 1]],
#    [-1, 1, Conv, [256, 3, 1]],
#    [-1, 1, Conv, [256, 3, 1]],
#    [[-1, -3, -5, -6], 1, Concat, [1]],
#    [-1, 1, Conv, [1024, 1, 1]],  # 37
#
#    [-1, 1, MP, []],
#    [-1, 1, Conv, [512, 1, 1]],
#    [-3, 1, Conv, [512, 1, 1]],
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, -3], 1, Concat, [1]],  # 42-P5/32
#    [-1, 1, Conv, [256, 1, 1]],
#    [-2, 1, Conv, [256, 1, 1]],
#    [-1, 1, Conv, [256, 3, 1]],
#    [-1, 1, Conv, [256, 3, 1]],
#    [-1, 1, Conv, [256, 3, 1]],
#    [-1, 1, Conv, [256, 3, 1]],
#    [[-1, -3, -5, -6], 1, Concat, [1]],
#    [-1, 1, Conv, [1024, 1, 1]],  # 50
#   ]
#
# # yolov7 head
# head:
#   [[-1, 1, SPPCSPC, [512]], # 51
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [37, 1, Conv, [256, 1, 1]], # route backbone P4
#    [[-1, -2], 1, Concat, [1]],
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-2, 1, Conv, [256, 1, 1]],
#    [-1, 1, Conv, [128, 3, 1]],
#    [-1, 1, Conv, [128, 3, 1]],
#    [-1, 1, Conv, [128, 3, 1]],
#    [-1, 1, Conv, [128, 3, 1]],
#    [[-1, -2, -3, -4, -5, -6], 1, Concat, [1]],
#    [-1, 1, Conv, [256, 1, 1]], # 63
#
#    [-1, 1, Conv, [128, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [24, 1, Conv, [128, 1, 1]], # route backbone P3
#    [[-1, -2], 1, Concat, [1]],
#
#    [-1, 1, Conv, [128, 1, 1]],
#    [-2, 1, Conv, [128, 1, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [[-1, -2, -3, -4, -5, -6], 1, Concat, [1]],
#    [-1, 1, Conv, [128, 1, 1]], # 75
#
#    [-1, 1, MP, []],
#    [-1, 1, Conv, [128, 1, 1]],
#    [-3, 1, Conv, [128, 1, 1]],
#    [-1, 1, Conv, [128, 3, 2]],
#    [[-1, -3, 63], 1, Concat, [1]],
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-2, 1, Conv, [256, 1, 1]],
#    [-1, 1, Conv, [128, 3, 1]],
#    [-1, 1, Conv, [128, 3, 1]],
#    [-1, 1, Conv, [128, 3, 1]],
#    [-1, 1, Conv, [128, 3, 1]],
#    [[-1, -2, -3, -4, -5, -6], 1, Concat, [1]],
#    [-1, 1, Conv, [256, 1, 1]], # 88
#
#    [-1, 1, MP, []],
#    [-1, 1, Conv, [256, 1, 1]],
#    [-3, 1, Conv, [256, 1, 1]],
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, -3, 51], 1, Concat, [1]],
#
#    [-1, 1, Conv, [512, 1, 1]],
#    [-2, 1, Conv, [512, 1, 1]],
#    [-1, 1, Conv, [256, 3, 1]],
#    [-1, 1, Conv, [256, 3, 1]],
#    [-1, 1, Conv, [256, 3, 1]],
#    [-1, 1, Conv, [256, 3, 1]],
#    [[-1, -2, -3, -4, -5, -6], 1, Concat, [1]],
#    [-1, 1, Conv, [512, 1, 1]], # 101
#
#    [75, 1, RepConv, [256, 3, 1]],
#    [88, 1, RepConv, [512, 3, 1]],
#    [101, 1, RepConv, [1024, 3, 1]],
#
#    [[102,103,104], 1, IDetect, [nc, anchors]],   # Detect(P3, P4, P5)
#   ]

# %%
# !cat /content/yolov7/cfg/training/custom_yolov7.yaml
# Out:
# # parameters
# nc: 29  # number of classes
# depth_multiple: 1.0  # model depth multiple
# width_multiple: 1.0  # layer channel multiple
#
# # anchors
# anchors:
#   - [12,16, 19,36, 40,28]  # P3/8
#   - [36,75, 76,55, 72,146]  # P4/16
#   - [142,110, 192,243, 459,401]  # P5/32
#
# # yolov7 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [32, 3, 1]],  # 0
#
#    [-1, 1, Conv, [64, 3, 2]],  # 1-P1/2
#    [-1, 1, Conv, [64, 3, 1]],
#
#    [-1, 1, Conv, [128, 3, 2]],  # 3-P2/4
#    [-1, 1, Conv, [64, 1, 1]],
#    [-2, 1, Conv, [64, 1, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [-1, 1, Conv, [64, 3, 1]],
#    [[-1, -3, -5, -6], 1, Concat, [1]],
#    [-1, 1, Conv, [256, 1, 1]],  # 11
#
#    [-1, 1, MP, []],
#    [-1, 1, Conv, [128, 1, 1]],
#    [-3, 1, Conv, [128, 1, 1]],
#    [-1, 1, Conv, [128, 3, 2]],
#    [[-1, -3], 1, Concat, [1]],  # 16-P3/8
#    [-1, 1, Conv, [128, 1, 1]],
# ...

# %%
# tiny yaml 만들기..
# !cat /content/yolov7/cfg/training/yolov7-tiny.yaml
# Out:
# # parameters
# nc: 80  # number of classes
# depth_multiple: 1.0  # model depth multiple
# width_multiple: 1.0  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # yolov7-tiny backbone
# backbone:
#   # [from, number, module, args] c2, k=1, s=1, p=None, g=1, act=True
#   [[-1, 1, Conv, [32, 3, 2, None, 1, nn.LeakyReLU(0.1)]],  # 0-P1/2
#
#    [-1, 1, Conv, [64, 3, 2, None, 1, nn.LeakyReLU(0.1)]],  # 1-P2/4
#
#    [-1, 1, Conv, [32, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [32, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [32, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [32, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 7
#
#    [-1, 1, MP, []],  # 8-P3/8
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
# ...

# %%
# %%writetemplate /content/yolov7/cfg/training/custom_yolov7-tiny.yaml
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 1.0  # model depth multiple
# width_multiple: 1.0  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # yolov7-tiny backbone
# backbone:
#   # [from, number, module, args] c2, k=1, s=1, p=None, g=1, act=True
#   [[-1, 1, Conv, [32, 3, 2, None, 1, nn.LeakyReLU(0.1)]],  # 0-P1/2
#
#    [-1, 1, Conv, [64, 3, 2, None, 1, nn.LeakyReLU(0.1)]],  # 1-P2/4
#
#    [-1, 1, Conv, [32, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [32, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [32, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [32, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 7
#
#    [-1, 1, MP, []],  # 8-P3/8
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [64, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [64, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 14
#
#    [-1, 1, MP, []],  # 15-P4/16
#    [-1, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [128, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [128, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 21
#
#    [-1, 1, MP, []],  # 22-P5/32
#    [-1, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [256, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [256, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [512, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 28
#   ]
#
# # yolov7-tiny head
# head:
#   [[-1, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, SP, [5]],
#    [-2, 1, SP, [9]],
#    [-3, 1, SP, [13]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -7], 1, Concat, [1]],
#    [-1, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 37
#
#    [-1, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [21, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]], # route backbone P4
#    [[-1, -2], 1, Concat, [1]],
#
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [64, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [64, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 47
#
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [14, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]], # route backbone P3
#    [[-1, -2], 1, Concat, [1]],
#
#    [-1, 1, Conv, [32, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [32, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [32, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [32, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 57
#
#    [-1, 1, Conv, [128, 3, 2, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, 47], 1, Concat, [1]],
#
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [64, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [64, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 65
#
#    [-1, 1, Conv, [256, 3, 2, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, 37], 1, Concat, [1]],
#
#    [-1, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [128, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [128, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 73
#
#    [57, 1, Conv, [128, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [65, 1, Conv, [256, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [73, 1, Conv, [512, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#
#    [[74,75,76], 1, IDetect, [nc, anchors]],   # Detect(P3, P4, P5)
#   ]

# %%
# !cat /content/yolov7/cfg/training/custom_yolov7-tiny.yaml
# Out:
# # parameters
# nc: 29  # number of classes
# depth_multiple: 1.0  # model depth multiple
# width_multiple: 1.0  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # yolov7-tiny backbone
# backbone:
#   # [from, number, module, args] c2, k=1, s=1, p=None, g=1, act=True
#   [[-1, 1, Conv, [32, 3, 2, None, 1, nn.LeakyReLU(0.1)]],  # 0-P1/2
#
#    [-1, 1, Conv, [64, 3, 2, None, 1, nn.LeakyReLU(0.1)]],  # 1-P2/4
#
#    [-1, 1, Conv, [32, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [32, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [32, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [32, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 7
#
#    [-1, 1, MP, []],  # 8-P3/8
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
# ...

# %%
import wget
wget.download('https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-tiny.pt')
# Out:
# 'yolov7-tiny.pt'

# %%
import torch

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
path = '/content/yolov7/yolov7-tiny.pt'
model = torch.hub.load("WongKinYiu/yolov7","custom",f"{path}",trust_repo=True)
# Out:
# Using cache found in /root/.cache/torch/hub/WongKinYiu_yolov7_main
# Adding autoShape...

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'list'> 80
# ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
# %cd /content/yolov7
# %pwd
# Out:
# /content/yolov7
# '/content/yolov7'

# %%
# !python train.py --workers 1 --device 0 --batch-size 32 --epochs 20 --img 1024 --data /content/drive/MyDrive/hjh_kita_directory/3rd_project/장애물탐지/obstacles_data_ver4/custom_data.yaml --hyp /content/yolov7/data/hyp.scratch.custom.yaml --cfg /content/yolov7/cfg/training/custom_yolov7-tiny.yaml --name yolov7-custom --weights /content/yolov7/yolov7-tiny.pt
# Out:
# 2024-04-09 06:49:47.362672: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-09 06:49:47.362724: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-09 06:49:47.364180: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-09 06:49:48.429764: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YOLOR 🚀 v0.1-128-ga207844 torch 2.2.1+cu121 CUDA:0 (Tesla T4, 15102.0625MB)
#
# ...

# %%
# !cp /content/yolov7/runs/train/yolov7-custom3/weights/best.pt /content/drive/MyDrive/hjh_kita_directory/3rd_project/0409

# %%
model_path = '/content/yolov7/runs/train/yolov7-custom3/weights/best.pt'
model = torch.load(model_path)['model']

# model.names를 통해 클래스 이름을 가져와 출력합니다.
print(type(model.names), len(model.names))
print(model.names)
# Out:
# <class 'list'> 29
# ['person', 'bicycle', 'car', 'motorcycle', 'bus', 'tree_trunk', 'traffic_light', 'stop', 'carrier', 'cat', 'dog', 'movable_signage', 'scooter', 'stroller', 'truck', 'wheelchair', 'barricade', 'bench', 'bollard', 'chair', 'fire_hydrant', 'kiosk', 'parking_meter', 'pole', 'potted_plant', 'power_controller', 'table', 'traffic_light_controller', 'traffic_sign']

# %%
from IPython.display import Image, display
Image(filename='/content/yolov7/runs/train/yolov7-custom3/confusion_matrix.png',width=1000)

# %%
from IPython.display import Image, display
Image(filename='/content/yolov7/runs/train/yolov7-custom3/train_batch0.jpg',width=1000)

# %%
Image(filename='/content/yolov7/runs/train/yolov7-custom3/test_batch0_labels.jpg',width=1000)

# %%
Image(filename='/content/yolov7/runs/train/yolov7-custom3/test_batch0_pred.jpg',width=1000)

# %%
Image(filename='/content/yolov7/runs/train/yolov7-custom3/test_batch1_pred.jpg',width=1000)

# %%
Image(filename='/content/yolov7/runs/train/yolov7-custom3/test_batch1_labels.jpg',width=1000)

# %%
Image(filename='/content/yolov7/runs/train/yolov7-custom3/F1_curve.png',width=1000)

# %%
# !python detect.py --weights /content/yolov7/runs/train/yolov7-custom3/weights/best.pt --conf 0.35 --source /content/drive/MyDrive/hjh_kita_directory/3rd_project/인서님
# Out:
# Namespace(weights=['/content/yolov7/runs/train/yolov7-custom3/weights/best.pt'], source='/content/drive/MyDrive/hjh_kita_directory/3rd_project/인서님', img_size=640, conf_thres=0.35, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.2.1+cu121 CUDA:0 (Tesla T4, 15102.0625MB)
#
# Fusing layers...
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 208 layers, 6083364 parameters, 0 gradients, 13.3 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/yolov7/runs/detect/exp/*.jpg')[:5]:
      display(Image(filename=image_path, height=600))
      print('\n')
